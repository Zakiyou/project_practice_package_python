# %%
! pip install psutil
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (6.0.0)

# %%
import psutil
import platform
from datetime import datetime

# %%
def get_size(bytes, suffix="B"):
    """
    Convertit les octets en format lisible (KB, MB, GB, etc.)
    """
    factor = 1024
    for unit in ["", "K", "M", "G", "T", "P"]:
        if bytes < factor:
            return f"{bytes:.2f}{unit}{suffix}"
        bytes /= factor

# %%
def get_os_info():
    """
    Récupère les informations sur le système d'exploitation
    """
    os_info = {
        "Système": platform.system(),
        "Nom du système": platform.node(),
        "Version": platform.version(),
        "Version de l'OS": platform.platform(),
        "Machine": platform.machine(),
        "Processeur": platform.processor(),
    }
    return os_info

# %%
def get_cpu_info():
    """
    Récupère les informations sur le processeur
    """
    cpu_info = {
        "Nom du processeur": platform.processor(),
        "Fréquence actuelle": f"{psutil.cpu_freq().current:.2f}Mhz",
        "Nombre de cœurs physiques": psutil.cpu_count(logical=False),
        "Nombre de threads": psutil.cpu_count(logical=True),
        "Utilisation du CPU par cœur": psutil.cpu_percent(percpu=True),
        "Utilisation totale du CPU": f"{psutil.cpu_percent()}%",
    }
    return cpu_info

# %%
def get_memory_info():
    """
    Récupère les informations sur la mémoire RAM
    """
    svmem = psutil.virtual_memory()
    memory_info = {
        "Mémoire totale": get_size(svmem.total),
        "Mémoire disponible": get_size(svmem.available),
        "Mémoire utilisée": get_size(svmem.used),
        "Pourcentage utilisé": f"{svmem.percent}%",
    }
    return memory_info

# %%
def get_swap_info():
    """
    Récupère les informations sur la mémoire swap
    """
    swap = psutil.swap_memory()
    swap_info = {
        "Swap total": get_size(swap.total),
        "Swap utilisé": get_size(swap.used),
        "Swap libre": get_size(swap.free),
        "Pourcentage utilisé": f"{swap.percent}%",
    }
    return swap_info

# %%
def get_disk_info():
    """
    Récupère les informations sur les disques
    """
    partitions = psutil.disk_partitions()
    disk_info = {}
    for partition in partitions:
        try:
            usage = psutil.disk_usage(partition.mountpoint)
        except PermissionError:
            continue
        disk_info[partition.device] = {
            "Point de montage": partition.mountpoint,
            "Système de fichiers": partition.fstype,
            "Taille totale": get_size(usage.total),
            "Utilisé": get_size(usage.used),
            "Libre": get_size(usage.free),
            "Pourcentage utilisé": f"{usage.percent}%",
        }
    return disk_info

# %%
def get_battery_info():
    """
    Récupère les informations sur la batterie
    """
    battery = psutil.sensors_battery()
    if battery:
        battery_info = {
            "Pourcentage de la batterie": f"{battery.percent}%",
            "Rechargeable": battery.power_plugged,
            "Temps restant": str(datetime.timedelta(seconds=battery.secsleft)) if battery.secsleft != psutil.POWER_TIME_UNLIMITED else "Illimité",
        }
    else:
        battery_info = {"Batterie": "Non détectée"}
    return battery_info

# %%
def get_network_info():
    """
    Récupère les informations sur le réseau
    """
    net_io = psutil.net_io_counters()
    network_info = {
        "Bytes envoyés": get_size(net_io.bytes_sent),
        "Bytes reçus": get_size(net_io.bytes_recv),
    }
    return network_info

# %%
def main():
    print("="*40, "INFORMATIONS SUR LE SYSTÈME", "="*40)
    print("\n** Informations sur le système d'exploitation **")
    os_info = get_os_info()
    for key, value in os_info.items():
        print(f"{key}: {value}")

    print("\n** Informations sur le processeur **")
    cpu_info = get_cpu_info()
    for key, value in cpu_info.items():
        print(f"{key}: {value}")

    print("\n** Informations sur la mémoire RAM **")
    memory_info = get_memory_info()
    for key, value in memory_info.items():
        print(f"{key}: {value}")

    print("\n** Informations sur la mémoire Swap **")
    swap_info = get_swap_info()
    for key, value in swap_info.items():
        print(f"{key}: {value}")

    print("\n** Informations sur les disques **")
    disk_info = get_disk_info()
    for device, info in disk_info.items():
        print(f"\n*** {device} ***")
        for key, value in info.items():
            print(f"{key}: {value}")

    print("\n** Informations sur la batterie **")
    battery_info = get_battery_info()
    for key, value in battery_info.items():
        print(f"{key}: {value}")

    print("\n** Informations sur le réseau **")
    network_info = get_network_info()
    for key, value in network_info.items():
        print(f"{key}: {value}")

    print("\n", "="*90)

# %%
if __name__ == "__main__":
    main()
# Out:
# ======================================== INFORMATIONS SUR LE SYSTÈME ========================================
#
# ** Informations sur le système d'exploitation **
# Système: Linux
# Nom du système: zakiyou-Precision-7520
# Version: #40~22.04.3-Ubuntu SMP PREEMPT_DYNAMIC Tue Jul 30 17:30:19 UTC 2
# Version de l'OS: Linux-6.8.0-40-generic-x86_64-with-glibc2.35
# Machine: x86_64
# Processeur: x86_64
#
# ** Informations sur le processeur **
# Nom du processeur: x86_64
# Fréquence actuelle: 3251.04Mhz
# Nombre de cœurs physiques: 4
# Nombre de threads: 8
# Utilisation du CPU par cœur: [10.2, 11.0, 10.3, 11.0, 10.9, 9.5, 11.1, 11.6]
# Utilisation totale du CPU: 10.7%
#
# ** Informations sur la mémoire RAM **
# Mémoire totale: 15.47GB
# Mémoire disponible: 3.90GB
# Mémoire utilisée: 9.60GB
# Pourcentage utilisé: 74.8%
#
# ** Informations sur la mémoire Swap **
# Swap total: 2.00GB
# Swap utilisé: 996.50MB
# Swap libre: 1.03GB
# Pourcentage utilisé: 48.7%
#
# ** Informations sur les disques **
#
# *** /dev/nvme0n1p5 ***
# Point de montage: /var/snap/firefox/common/host-hunspell
# Système de fichiers: ext4
# Taille totale: 229.64GB
# Utilisé: 101.62GB
# Libre: 116.28GB
# Pourcentage utilisé: 46.6%
#
# *** /dev/loop0 ***
# Point de montage: /snap/bare/5
# Système de fichiers: squashfs
# Taille totale: 128.00KB
# Utilisé: 128.00KB
# Libre: 0.00B
# Pourcentage utilisé: 100.0%
#
# *** /dev/loop1 ***
# Point de montage: /snap/core18/2823
# Système de fichiers: squashfs
# Taille totale: 55.75MB
# Utilisé: 55.75MB
# Libre: 0.00B
# Pourcentage utilisé: 100.0%
#
# *** /dev/loop2 ***
# Point de montage: /snap/core18/2829
# Système de fichiers: squashfs
# Taille totale: 55.75MB
# Utilisé: 55.75MB
# Libre: 0.00B
# Pourcentage utilisé: 100.0%
#
# *** /dev/loop4 ***
# Point de montage: /snap/core20/2318
# Système de fichiers: squashfs
# Taille totale: 64.00MB
# Utilisé: 64.00MB
# Libre: 0.00B
# Pourcentage utilisé: 100.0%
#
# *** /dev/loop7 ***
# Point de montage: /snap/curl/1754
# Système de fichiers: squashfs
# Taille totale: 6.50MB
# Utilisé: 6.50MB
# Libre: 0.00B
# Pourcentage utilisé: 100.0%
#
# *** /dev/loop8 ***
# Point de montage: /snap/firefox/4698
# Système de fichiers: squashfs
# Taille totale: 269.88MB
# Utilisé: 269.88MB
# Libre: 0.00B
# Pourcentage utilisé: 100.0%
#
# *** /dev/loop6 ***
# Point de montage: /snap/core22/1586
# Système de fichiers: squashfs
# Taille totale: 74.38MB
# Utilisé: 74.38MB
# Libre: 0.00B
# Pourcentage utilisé: 100.0%
#
# *** /dev/loop9 ***
# Point de montage: /snap/firefox/4793
# Système de fichiers: squashfs
# Taille totale: 269.88MB
# Utilisé: 269.88MB
# Libre: 0.00B
# Pourcentage utilisé: 100.0%
#
# *** /dev/loop11 ***
# Point de montage: /snap/flutter-gallery/54
# Système de fichiers: squashfs
# Taille totale: 95.25MB
# Utilisé: 95.25MB
# Libre: 0.00B
# Pourcentage utilisé: 100.0%
#
# *** /dev/loop12 ***
# Point de montage: /snap/gnome-3-38-2004/143
# Système de fichiers: squashfs
# Taille totale: 349.75MB
# Utilisé: 349.75MB
# Libre: 0.00B
# Pourcentage utilisé: 100.0%
#
# *** /dev/loop10 ***
# Point de montage: /snap/gnome-3-28-1804/198
# Système de fichiers: squashfs
# Taille totale: 164.88MB
# Utilisé: 164.88MB
# Libre: 0.00B
# Pourcentage utilisé: 100.0%
#
# *** /dev/loop13 ***
# Point de montage: /snap/gnome-3-38-2004/99
# Système de fichiers: squashfs
# Taille totale: 248.88MB
# Utilisé: 248.88MB
# Libre: 0.00B
# Pourcentage utilisé: 100.0%
#
# *** /dev/loop14 ***
# Point de montage: /snap/gnome-42-2204/141
# Système de fichiers: squashfs
# Taille totale: 497.00MB
# Utilisé: 497.00MB
# Libre: 0.00B
# Pourcentage utilisé: 100.0%
#
# *** /dev/loop15 ***
# Point de montage: /snap/gnome-42-2204/176
# Système de fichiers: squashfs
# Taille totale: 505.12MB
# Utilisé: 505.12MB
# Libre: 0.00B
# Pourcentage utilisé: 100.0%
#
# *** /dev/loop16 ***
# Point de montage: /snap/gtk-common-themes/1534
# Système de fichiers: squashfs
# Taille totale: 81.38MB
# Utilisé: 81.38MB
# Libre: 0.00B
# Pourcentage utilisé: 100.0%
#
# *** /dev/loop17 ***
# Point de montage: /snap/gtk-common-themes/1535
# Système de fichiers: squashfs
# Taille totale: 91.75MB
# Utilisé: 91.75MB
# Libre: 0.00B
# Pourcentage utilisé: 100.0%
#
# *** /dev/loop18 ***
# Point de montage: /snap/ollama/15
# Système de fichiers: squashfs
# Taille totale: 452.75MB
# Utilisé: 452.75MB
# Libre: 0.00B
# Pourcentage utilisé: 100.0%
#
# *** /dev/loop19 ***
# Point de montage: /snap/snap-store/1113
# Système de fichiers: squashfs
# Taille totale: 13.00MB
# Utilisé: 13.00MB
# Libre: 0.00B
# Pourcentage utilisé: 100.0%
#
# *** /dev/loop20 ***
# Point de montage: /snap/snap-store/959
# Système de fichiers: squashfs
# Taille totale: 12.38MB
# Utilisé: 12.38MB
# Libre: 0.00B
# Pourcentage utilisé: 100.0%
#
# *** /dev/loop21 ***
# Point de montage: /snap/snapd/21465
# Système de fichiers: squashfs
# Taille totale: 38.75MB
# Utilisé: 38.75MB
# Libre: 0.00B
# Pourcentage utilisé: 100.0%
#
# *** /dev/loop22 ***
# Point de montage: /snap/snapd/21759
# Système de fichiers: squashfs
# Taille totale: 38.88MB
# Utilisé: 38.88MB
# Libre: 0.00B
# Pourcentage utilisé: 100.0%
#
# *** /dev/loop23 ***
# Point de montage: /snap/snapd-desktop-integration/157
# Système de fichiers: squashfs
# Taille totale: 512.00KB
# Utilisé: 512.00KB
# Libre: 0.00B
# Pourcentage utilisé: 100.0%
#
# *** /dev/loop24 ***
# Point de montage: /snap/snapd-desktop-integration/178
# Système de fichiers: squashfs
# Taille totale: 512.00KB
# Utilisé: 512.00KB
# Libre: 0.00B
# Pourcentage utilisé: 100.0%
#
# *** /dev/nvme0n1p2 ***
# Point de montage: /boot/efi
# Système de fichiers: vfat
# Taille totale: 96.00MB
# Utilisé: 41.16MB
# Libre: 54.84MB
# Pourcentage utilisé: 42.9%
#
# *** /dev/nvme0n1p4 ***
# Point de montage: /media/zakiyou/7466CAF366CAB4E0
# Système de fichiers: ntfs3
# Taille totale: 241.93GB
# Utilisé: 186.66GB
# Libre: 55.27GB
# Pourcentage utilisé: 77.2%
#
# *** /dev/loop25 ***
# Point de montage: /snap/core22/1621
# Système de fichiers: squashfs
# Taille totale: 74.25MB
# Utilisé: 74.25MB
# Libre: 0.00B
# Pourcentage utilisé: 100.0%
#
# *** /dev/loop5 ***
# Point de montage: /snap/core20/2379
# Système de fichiers: squashfs
# Taille totale: 64.00MB
# Utilisé: 64.00MB
# Libre: 0.00B
# Pourcentage utilisé: 100.0%
#
# *** /dev/sda2 ***
# Point de montage: /media/zakiyou/Nouveau nom
# Système de fichiers: ntfs3
# Taille totale: 931.50GB
# Utilisé: 143.03GB
# Libre: 788.47GB
# Pourcentage utilisé: 15.4%
#
# ** Informations sur la batterie **
# Pourcentage de la batterie: 100.0%
# Rechargeable: True
# Temps restant: Illimité
#
# ** Informations sur le réseau **
# Bytes envoyés: 1.36GB
# Bytes reçus: 2.90GB
#
#  ==========================================================================================
